# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv('C:/Users/ACER/Desktop/coapps/project/dataset.csv')

# %%
dataset.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
dataset.shape
# Out:
# (20800, 5)

# %%
dataset.isna().sum()
# Out:
# id           0
# title      558
# author    1957
# text        39
# label        0
# dtype: int64

# %%
dataset.dropna(axis = 0, inplace = True)

# %%
dataset.isna().sum()
# Out:
# id        0
# title     0
# author    0
# text      0
# label     0
# dtype: int64

# %%
dataset
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# ...

# %%
dataset.reset_index(inplace=True)
dataset
# Out:
#        index     id                                              title  \
# 0          0      0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1      1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2      2                  Why the Truth Might Get You Fired
# 3          3      3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4      4  Iranian woman jailed for fictional unpublished...
# ...      ...    ...                                                ...
# 18280  20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 18281  20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 18282  20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 18283  20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 18284  20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# ...

# %%
label_counts = dataset['label'].value_counts()
label_counts.plot(kind='bar', color='blue')
# Out:
# <Axes: xlabel='label'>

# %%
sns.countplot(data=dataset, x='label', palette='Blues')
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_1824\3215041627.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=dataset, x='label', palette='Blues')
# <Axes: xlabel='label', ylabel='count'>

# %%
data = dataset['title'][0]
data
# Out:
# 'House Dem Aide: We Didn’t Even See Comey’s Letter Until Jason Chaffetz Tweeted It'

# %%
import re
data = re.sub('[^a-zA-Z]',' ',data)

# %%
data = data.lower()
data
# Out:
# 'house dem aide  we didn t even see comey s letter until jason chaffetz tweeted it'

# %%
list = data.split()
list
# Out:
# ['house',
#  'dem',
#  'aide',
#  'we',
#  'didn',
#  't',
#  'even',
#  'see',
#  'comey',
#  's',
#  'letter',
#  'until',
#  'jason',
#  'chaffetz',
#  'tweeted',
#  'it']

# %%
#!pip install nltk
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()
review = [ps.stem(word) for word in list if word not in set(stopwords.words('english'))]

# %%
' '.join(review)
# Out:
# 'hous dem aid even see comey letter jason chaffetz tweet'

# %%
corpus = []
for i in range(0,len(dataset)):
  review = re.sub('[^a-zA-Z]',' ',dataset['title'][i])
  review = review.lower()
  list = review.split()
  review = [ps.stem(word) for word in list if not word in set(stopwords.words('english'))]
  corpus.append(' '.join(review))

# %%
corpus[0]
# Out:
# 'hous dem aid even see comey letter jason chaffetz tweet'

# %%
corpus
# Out:
# ['hous dem aid even see comey letter jason chaffetz tweet',
#  'flynn hillari clinton big woman campu breitbart',
#  'truth might get fire',
#  'civilian kill singl us airstrik identifi',
#  'iranian woman jail fiction unpublish stori woman stone death adulteri',
#  'jacki mason hollywood would love trump bomb north korea lack tran bathroom exclus video breitbart',
#  'beno hamon win french socialist parti presidenti nomin new york time',
#  'back channel plan ukrain russia courtesi trump associ new york time',
#  'obama organ action partner soro link indivis disrupt trump agenda',
#  'bbc comedi sketch real housew isi caus outrag',
#  'russian research discov secret nazi militari base treasur hunter arctic photo',
#  'us offici see link trump russia',
#  'ye paid govern troll social media blog forum websit',
#  'major leagu soccer argentin find home success new york time',
#  'well fargo chief abruptli step new york time',
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X = cv.fit_transform(corpus).toarray()

# %%
X.shape
# Out:
# (18285, 13913)

# %%
X[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y = dataset['label']

# %%
y.shape
# Out:
# (18285,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25, random_state = 0)

# %%
X_train.shape
# Out:
# (13713, 13913)

# %%
X_test.shape
# Out:
# (4572, 13913)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
from sklearn.metrics import confusion_matrix

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB()
classifier.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred
# Out:
# array([1, 0, 1, ..., 1, 0, 0], dtype=int64)

# %%
conf_matrix_naive = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix_naive, annot = True)
conf_matrix_naive
# Out:
# array([[2427,  156],
#        [ 290, 1699]], dtype=int64)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9024496937882764

# %%
# Assuming you have your true labels stored in y_true_naive and predicted labels in y_pred_naive

precision_naive = precision_score(y_test, y_pred)
recall_naive = recall_score(y_test, y_pred)
f1_naive = f1_score(y_test, y_pred)
print("Precision:", precision_naive)
print("Recall:", recall_naive)
print("F1-score:", f1_naive)
# Out:
# Precision: 0.9159029649595687
# Recall: 0.8541980894922071
# F1-score: 0.8839750260145681

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(X_test)
accuracy_score_ = accuracy_score(y_test,y_pred)
accuracy_score_
# Out:
# 0.928915135608049

# %%
precision_random_forest = precision_score(y_test,y_pred)
recall_random_forest = recall_score(y_test,y_pred)
f1_random_forest = f1_score(y_test,y_pred)
print("Precision:", precision_random_forest)
print("Recall:", recall_random_forest)
print("F1-score:", f1_random_forest)
# Out:
# Precision: 0.8764705882352941
# Recall: 0.9738562091503268
# F1-score: 0.9226006191950464

# %%
conf_matrix_random_forest = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix_random_forest, annot = True)
conf_matrix_random_forest
# Out:
# array([[2310,  273],
#        [  52, 1937]], dtype=int64)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(X_test)
accuracy_score_ = accuracy_score(y_test,y_pred)
accuracy_score_
# Out:
# 0.9175415573053368

# %%
precision_decision = precision_score(y_test,y_pred)
recall_decision = recall_score(y_test,y_pred)
f1_decision = f1_score(y_test,y_pred)
print("Precision:", precision_decision)
print("Recall:", recall_decision)
print("F1-score:", f1_decision)
# Out:
# Precision: 0.8860153256704981
# Recall: 0.930115635997989
# F1-score: 0.9075300466028943

# %%
conf_matrix_decision = confusion_matrix(y_test,y_pred)
sns.heatmap(conf_matrix_decision, annot = True)
conf_matrix_decision
# Out:
# array([[2345,  238],
#        [ 139, 1850]], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression
logistic_model = LogisticRegression()
logistic_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
y_pred = logistic_model.predict(X_test)
accuracy_score_ = accuracy_score(y_test, y_pred)
print(accuracy_score_)
# Out:
# 0.9313210848643919

# %%
precision_logistic = precision_score(y_test, y_pred)
recall_logistic = recall_score(y_test, y_pred)
f1_logistic = f1_score(y_test, y_pred)
print("Precision:", precision_logistic)
print("Recall:", recall_logistic)
print("F1-score:", f1_logistic)
# Out:
# Precision: 0.8871937124364309
# Recall: 0.9648064353946707
# F1-score: 0.924373795761079

# %%
conf_matrix_logistic = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix_logistic, annot = True)
conf_matrix_logistic
# Out:
# array([[2339,  244],
#        [  70, 1919]], dtype=int64)

# %%
from sklearn.linear_model import PassiveAggressiveClassifier
pa_model = PassiveAggressiveClassifier()
pa_model.fit(X_train, y_train)
# Out:
# PassiveAggressiveClassifier()

# %%
y_pred = pa_model.predict(X_test)
accuracy_score_ = accuracy_score(y_test,y_pred)
accuracy_score_
# Out:
# 0.9206036745406824

# %%
precision_pa = precision_score(y_test,y_pred)
recall_pa = recall_score(y_test,y_pred)
f1_pa = f1_score(y_test,y_pred)
print("Precision:", precision_pa)
print("Recall:", recall_pa)
print("F1-score:", f1_pa)
# Out:
# Precision: 0.900887573964497
# Recall: 0.918552036199095
# F1-score: 0.9096340552651232

# %%
conf_matrix_pa = confusion_matrix(y_test,y_pred)
sns.heatmap(conf_matrix_pa, annot = True)
conf_matrix_pa
# Out:
# array([[2382,  201],
#        [ 162, 1827]], dtype=int64)

# %%
import xgboost as xgb
xgb_model = xgb.XGBClassifier()
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = xgb_model.predict(X_test)
accuracy_score_ = accuracy_score(y_test,y_pred)
accuracy_score_
# Out:
# 0.9238845144356955

# %%
precision_xgboost = precision_score(y_test,y_pred)
recall_xgboost = recall_score(y_test,y_pred)
f1_xgboost = f1_score(y_test,y_pred)
print("Precision:", precision_xgboost)
print("Recall:", recall_xgboost)
print("F1-score:", f1_xgboost)
# Out:
# Precision: 0.8632138114209827
# Recall: 0.9803921568627451
# F1-score: 0.9180790960451978

# %%
conf_matrix_xgboost = confusion_matrix(y_test,y_pred)
sns.heatmap(conf_matrix_xgboost, annot = True)
conf_matrix_xgboost
# Out:
# array([[2274,  309],
#        [  39, 1950]], dtype=int64)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn_model.predict(X_test)
accuracy_score_ = accuracy_score(y_test,y_pred)
accuracy_score_
# Out:
# 0.7832458442694663

# %%
precision_knn = precision_score(y_test,y_pred)
recall_knn = recall_score(y_test,y_pred)
f1_knn = f1_score(y_test,y_pred)
print("Precision:", precision_knn)
print("Recall:", recall_knn)
print("F1-score:", f1_knn)
# Out:
# Precision: 0.6680134680134681
# Recall: 0.9974861739567622
# F1-score: 0.8001613228473483

# %%
conf_matrix_knn = confusion_matrix(y_test,y_pred)
sns.heatmap(conf_matrix_knn, annot = True)
conf_matrix_knn
# Out:
# array([[1597,  986],
#        [   5, 1984]], dtype=int64)

# %%
from joblib import dump
dump(logistic_model,"Fake_News.pkl")
# Out:
# ['Fake_News.pkl']

# %%
from joblib import load
loaded_logistic_model = load("Fake_News.pkl")

# %%
import joblib

# Fit the CountVectorizer to your corpus
cv.fit(corpus)
# Save the trained CountVectorizer to a .pkl file
joblib.dump(cv, "count_vectorizer.pkl")
# Out:
# ['count_vectorizer.pkl']

# %%
import joblib
# Load the trained CountVectorizer from the .pkl file
cv = joblib.load("count_vectorizer.pkl")
